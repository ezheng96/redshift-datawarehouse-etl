# %% [markdown]
# # IaC set-up for Project-3 AWS Redshift

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# ## STEP 0: Make sure you have an AWS secret and access key

# %% [markdown]
# - Create a new IAM user in your AWS account
# - Give it AdministratorAccess, From Attach existing policies directly Tab
# - Take note of the access key and secret
# - Edit the file dwh.cfg in the same folder as this notebook and fill
#
# [AWS]
#
# KEY= YOUR_AWS_KEY
#
# SECRET= YOUR_AWS_SECRET

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

# NOTE: Un-comment this to print the result.
pd.DataFrame({"Param":
                 ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
             "Value":
                 [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
            })
# Out:
#                     Param               Value
# 0        DWH_CLUSTER_TYPE          multi-node
# 1           DWH_NUM_NODES                   4
# 2           DWH_NODE_TYPE           dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  redshift-cluster-1
# 4                  DWH_DB                 dwh
# 5             DWH_DB_USER       redshift_user
# 6         DWH_DB_PASSWORD      UdacityDegree1
# 7                DWH_PORT                5439
# 8       DWH_IAM_ROLE_NAME             dwhRole

# %%
import boto3

ec2 = boto3.resource(   'ec2', 
                      region_name="us-west-2",
                      aws_access_key_id=KEY,
                      aws_secret_access_key=SECRET)

s3 = boto3.resource(  's3',
                    region_name="us-west-2",
                    aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET)

iam = boto3.client('iam',
                    region_name="us-west-2",
                    aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET)

redshift = boto3.client('redshift',
                        region_name="us-west-2",
                        aws_access_key_id=KEY,
                        aws_secret_access_key=SECRET)

# %%
LOG_DATA      = config.get("S3", "BUCKET")
logDataBucket = s3.Bucket(LOG_DATA)
count = 0

# Iterate over log_data bucket objects and print
for object in logDataBucket.objects.filter(Prefix='log_data'):
    count += 1
    print(object)
print("COUNT: " + str(count))
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-01-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-02-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-03-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-04-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-05-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-06-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-07-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-08-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-09-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-10-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-11-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-12-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-13-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-14-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-15-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-16-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-17-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-18-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-19-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-20-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-21-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-22-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-23-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-24-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-25-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-26-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-27-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-28-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-29-events.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-30-events.json')
# COUNT: 31

# %%
SONG_DATA      = config.get("S3", "BUCKET")
songDataBucket = s3.Bucket(SONG_DATA)
count = 0

# Iterate over song_data bucket objects and print
for object in logDataBucket.objects.filter(Prefix='song_data'):
    count += 1
    print(object)
print("COUNT: " + str(count))

# %% [markdown]
# ## STEP 1: Create an IAM Role to allow redshift to access S3

# %%
# Create the IAM role (if not exists)

try:
    print('1.1 Creating a new IAM Role')
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description="Allow Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
                'Effect': 'Allow',
                'Principal': {'Service': 'redshift.amazonaws.com'}}],
            'Version': '2012-10-17'})
    )
    

except Exception as e:
    print(e)
# Out:
# 1.1 Creating a new IAM Role
# An error occurred (EntityAlreadyExists) when calling the CreateRole operation: Role with name dwhRole already exists.

# %%
# Attach Policy

print('1.2 Attaching Policy')
iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                      PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']
# Out:
# 1.2 Attaching Policy
# 200

# %%
# Get and print the IAM role ARN
print('1.3 Get the IAM role ARN')
iam_role = iam.get_role(
                        RoleName=DWH_IAM_ROLE_NAME
                        )
roleArn = iam_role['Role']['Arn']
# NOTE: Un-comment this to print the result.
print(roleArn)
# Out:
# 1.3 Get the IAM role ARN
# arn:aws:iam::898892311929:role/dwhRole

# %% [markdown]
# ## STEP 2: Create Redshift Cluster

# %% [markdown]
# - Create a RedShift Cluster
# - For complete arguments to create_cluster, see docs

# %%
try:
    response = redshift.create_cluster( 
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        IamRoles=[roleArn]
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## 2.1 Describe the cluster to see its status

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
# NOTE: Un-comment this to print the result.
prettyRedshiftProps(myClusterProps)
# Out:
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
# 7  NumberOfNodes
#
#                                                                                            Value
# 0  redshift-cluster-1
# 1  dc2.large
# 2  available
# 3  redshift_user
# 4  dwh
# 5  {'Address': 'redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-0dcf3b7e358c345b0
# 7  4

# %% [markdown]
# ## 2.2 Take note of the cluster endpoint and role ARN
# DO NOT RUN THIS unless the cluster status becomes "Available"

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']

print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::898892311929:role/dwhRole

# %% [markdown]
# ## STEP 3: Open an incoming TCP port to access the cluster endpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    print(vpc)
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    
    defaultSg.authorize_ingress(
        GroupName= defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP', 
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.Vpc(id='vpc-0dcf3b7e358c345b0')
# ec2.SecurityGroup(id='sg-06b0bfcb9dfb7e7d9')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %% [markdown]
# ## STEP 4: Make sure you can connect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT, 'dwh')
# NOTE: Un-comment this to print the result.
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://redshift_user:UdacityDegree1@redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com:5439/dwh
# 'Connected: redshift_user@dwh'

# %% [markdown]
# ### Step 5: Analytical Queries

# %% [markdown]
# #### Queries to check count of staging tables:

# %%
# %sql SELECT COUNT(*) FROM staging_events;
# Out:
#  * postgresql://redshift_user:***@redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(8056,)]

# %%
# %sql SELECT COUNT(*) FROM staging_songs;
# Out:
#  * postgresql://redshift_user:***@redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(14896,)]

# %% [markdown]
# #### Query to answer a question: Who played which song and when.

# %%
# %%sql
# SELECT  sp.songplay_id,
#         u.user_id,
#         u.last_name,
#         u.first_name,
#         sp.start_time,
#         a.name,
#         s.title
# FROM songplays AS sp
#         JOIN users   AS u ON (u.user_id = sp.user_id)
#         JOIN songs   AS s ON (s.song_id = sp.song_id)
#         JOIN artists AS a ON (a.artist_id = sp.artist_id)
#         JOIN time    AS t ON (t.start_time = sp.start_time)
# ORDER BY (u.last_name)
# LIMIT 100;
# Out:
#  * postgresql://redshift_user:***@redshift-cluster-1.cvzum3b8mpnr.us-west-2.redshift.amazonaws.com:5439/dwh
# 100 rows affected.
# [(8247, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 0, 40, 37), 'Fu', 'Nie Mów Mi'),
#  (7560, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Wicker Chair'),
#  (631, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Would It Matter (Bonus Track)'),
#  (7322, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 5, 56, 58), 'The Cinematic Orchestra', 'Dawn'),
#  (6286, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Catcher In The Rye'),
#  (9679, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Rumore'),
#  (640, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Rebirthing (Album Version)'),
#  (5471, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 31, 32), 'Benga', 'Zero M2'),
#  (972, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'Brother'),
#  (168, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 10, 12, 44, 10), 'Juanes', 'Rebelion'),
#  (1313, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'God Smack'),
#  (7322, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 5, 56, 58), 'The Cinematic Orchestra/London Metropolitan Orchestra', 'Dawn'),
#  (9296, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Suncanom stranom'),
#  (7552, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Genius'),
#  (638, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'The Older I Get [Acoustic]'),
#  (7610, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'El Maximo Daño'),
#  (7274, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Ragoo'),
#  (6502, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 6, 9, 6), 'Viola', 'My Troubled One'),
#  (1237, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 9, 30), 'Lily Allen', 'U Killed It'),
#  (3005, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'If Ever'),
#  (821, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 50, 45), 'Talking Heads', 'Two Note Swivel (Unfinished Outtake)'),
#  (8945, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Dok je tebe'),
#  (7639, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 39, 56), 'Kings Of Leon', 'Day Old Blues'),
#  (9103, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Oba lica ljubavi'),
#  (6912, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 19, 10, 42), 'Evanescence', 'Missing (Live in Europe)'),
#  (3111, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'X-Static'),
#  (6784, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Mama Kin'),
#  (2306, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Still'),
#  (8733, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 25, 11), 'Parni Valjak', 'Zastave'),
#  (7764, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 21, 13, 57, 53), 'Rick James', 'She Blew My Mind (69 Times)'),
#  (2076, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 7, 25), 'Great Lake Swimmers', "River's Edge"),
#  (1081, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter feat. DJ Mental Theos Bazzheadz', 'Why'),
#  (7422, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 21, 13, 57, 53), 'Rick James', 'Mr. Policeman'),
#  (639, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Looking For Angels (Album Version)'),
#  (1783, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Suspended'),
#  (1081, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter', 'Why'),
#  (3067, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Next Year'),
#  (1385, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Maid'),
#  (6792, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", 'Locomotive (Complicity)'),
#  (7779, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 42, 32), 'Smash Mouth', 'Nervous In The Alley'),
#  (1816, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 27, 4, 48, 7), 'Alice In Chains', 'Lesson Learned'),
#  (7920, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Autentico'),
#  (9671, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Mezquindad'),
#  (2470, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 14, 24), 'Franz Ferdinand', 'Do You Want To'),
#  (7618, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 11), 'Soziedad Alkoholika', 'Va Bien'),
#  (1036, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 9, 30), 'Lily Allen', 'LDN (Warbox Original Cut Dub)'),
#  (1028, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 7, 12, 6, 23), 'Matt Nathanson', 'Little Victories'),
#  (3066, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter', 'Every Morning'),
#  (7626, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 29, 30), 'Flaw', 'Endangered Species'),
#  (3066, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 6, 7, 36, 46), 'Basshunter feat. DJ Mental Theos Bazzheadz', 'Every Morning'),
#  (3013, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Hell'),
#  (6724, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 55, 4), "Guns N' Roses", "You're Crazy"),
#  (626, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 2, 2, 42, 48), 'Skillet', 'Energy (Album Version)'),
#  (1494, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 41, 9), 'Townsend_ Devin', 'Hidden Track'),
#  (437, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 13, 32, 59), 'Eric B. & Rakim', 'Follow The Leader'),
#  (8475, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 13, 0, 40, 37), 'Fu', 'To Wszystko Co Mam'),
#  (4332, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 17, 16), 'Modest Mouse', 'The Whale Song'),
#  (2804, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 23, 0, 33, 55), 'Foo Fighters', 'Overdrive'),
#  (1494, 66, 'Arellano', 'Kevin', datetime.datetime(2018, 11, 12, 11, 41, 9), 'Devin Townsend', 'Hidden Track'),
#  (2667, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Fake Plastic Trees (Acoustic Version)'),
#  (9757, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 8, 43), 'Eminem', 'Ricky Ticky Toc'),
#  (2378, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Fast-Track'),
#  (9237, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'Skit #2 (Kanye West/Late Registration)'),
#  (9355, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 4, 36), 'Interpol', 'Wrecking Ball'),
#  (9500, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 15, 8, 43), 'Eminem', "I'm Back"),
#  (2683, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Stop Whispering (US Version)'),
#  (7822, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'Street Lights'),
#  (2625, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Subterranean Homesick Alien'),
#  (2675, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Pop Is Dead'),
#  (2646, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', '15 Step'),
#  (1853, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Bullet Proof ... I Wish I Was (Acoustic)'),
#  (9482, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 6, 14, 59, 25), 'Kanye West', 'School Spirit Skit 2'),
#  (2638, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 7, 11), 'Radiohead', 'Vegetable (Live)'),
#  (6294, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 11, 26), 'Lupe Fiasco', 'Streets On Fire (Explicit Album Version)'),
#  (6294, 34, 'Ayala', 'Evelin', datetime.datetime(2018, 11, 14, 13, 11, 26), 'Lupe Fiasco feat. Matthew Santos', 'Streets On Fire (Explicit Album Version)'),
#  (3915, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 4, 0, 50, 3), 'Professor Longhair', 'No Buts - No Maybes'),
#  (8167, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'People Can Fly'),
#  (8330, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'Power Gen'),
#  (8600, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 33, 5), 'Astral Projection', 'Ionized'),
#  (412, 99, 'Banks', 'Ann', datetime.datetime(2018, 11, 9, 15, 29, 15), 'Hot Chip', 'Hold On'),
#  (7565, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 28, 10, 48, 46), 'Concrete Blonde', 'Joey (Acoustic) (Live)'),
#  (1611, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'Riendose de mi'),
#  (5504, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'Speed Of Sound (Live)'),
#  (1483, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 57, 29), 'Linkin Park', 'Crawling (Album Version)'),
#  (6025, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 4, 16, 23, 7), 'Shaggy', 'Alimony'),
#  (5496, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'One I Love'),
#  (1146, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'Camino A La Paloma'),
#  (4998, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 20, 15, 50, 1), 'Lonnie Gordon', 'Catch You Baby (Wideboys Electro Remix)'),
#  (471, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 9, 17, 17, 1), 'Linkin Park', 'Crawling (Album Version)'),
#  (4894, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', 'A Rush Of Blood To The Head (Live In Sydney)'),
#  (1555, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'Heaven Only Knows'),
#  (4497, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 4, 16, 18, 48), 'Finger Eleven', 'Tip'),
#  (1605, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 2, 13, 25, 38), 'Jorge Drexler', 'No Pienses De Mas'),
#  (1664, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'The Avenue (Zack W. Remix)'),
#  (5870, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 4, 16, 23, 7), 'Shaggy', 'Criteria'),
#  (1106, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 12, 8, 58, 41), 'K-OS', 'Clap Ur Handz'),
#  (5495, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 20, 15, 50, 1), 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  (5512, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 52, 11), 'Coldplay', "Don't Panic"),
#  (9300, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 28, 10, 48, 46), 'Concrete Blonde', 'Valentine'),
#  (1006, 100, 'Barrera', 'Adler', datetime.datetime(2018, 11, 14, 15, 57, 29), 'Linkin Park', 'Given Up (Album Version)')]
